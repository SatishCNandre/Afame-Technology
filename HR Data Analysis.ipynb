# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("HR Data.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# The dataset comprises 1470 rows (ranging from 0 to 1469) and 35 columns, all of which are complete without any missing values, allowing us to move on to the next step.

# %% [markdown]
# #### Removing unnecessary columns.

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# #### Giving the columns new names.

# %%
# Remove unnecessary columns
df = df.drop(columns=['EmployeeCount', 'Over18', 'StandardHours'])

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeNumber  \
# ...

# %% [markdown]
# #### Rename Columns

# %%
# Renaming columns for better clarity (example names)
df = df.rename(columns={
    'Attrition': 'EmployeeAttrition',
    'BusinessTravel': 'TravelFrequency',
    'DailyRate': 'DailyIncome',
    # Add more renaming if needed
})

# %% [markdown]
# #### Eliminate Redundant Entries

# %%
# Remove duplicate rows
df = df.drop_duplicates()

# %% [markdown]
# #### Sanitize Specific Columns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Trim whitespace from string columns
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# Example of specific column sanitization
df['Department'] = df['Department'].str.title()  # Converting to title case

# %% [markdown]
# #### Eliminate NaN Values

# %%
# Remove rows with any NaN values
df = df.dropna()

# %% [markdown]
# #### Check for Inconsistent Data Entries

# %%
# Check unique values in categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns
unique_values = {col: df[col].unique() for col in categorical_columns}
unique_values
# Out:
# {'EmployeeAttrition': array(['Yes', 'No'], dtype=object),
#  'TravelFrequency': array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object),
#  'Department': array(['Sales', 'Research & Development', 'Human Resources'], dtype=object),
#  'EducationField': array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#         'Technical Degree', 'Human Resources'], dtype=object),
#  'Gender': array(['Female', 'Male'], dtype=object),
#  'JobRole': array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#         'Manufacturing Director', 'Healthcare Representative', 'Manager',
#         'Sales Representative', 'Research Director', 'Human Resources'],
#        dtype=object),
#  'MaritalStatus': array(['Single', 'Married', 'Divorced'], dtype=object),
#  'OverTime': array(['Yes', 'No'], dtype=object)}

# %% [markdown]
# #### Outlier Detection and Handling

# %%
from scipy import stats

numerical_columns = ['DailyIncome', 'Age']
z_scores = stats.zscore(df[numerical_columns])
abs_z_scores = abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
df_filtered = df[filtered_entries]
df_filtered
# Out:
#       Age EmployeeAttrition    TravelFrequency  DailyIncome  \
# 0      41               Yes      Travel_Rarely         1102
# 1      49                No  Travel_Frequently          279
# 2      37               Yes      Travel_Rarely         1373
# 3      33                No  Travel_Frequently         1392
# 4      27                No      Travel_Rarely          591
# ...   ...               ...                ...          ...
# 1465   36                No  Travel_Frequently          884
# 1466   39                No      Travel_Rarely          613
# 1467   27                No      Travel_Rarely          155
# 1468   49                No  Travel_Frequently         1023
# 1469   34                No      Travel_Rarely          628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# ...

# %% [markdown]
# #### Encode Categorical Variables

# %%
# Convert the categorical columns to 'category' dtype
df[categorical_columns] = df[categorical_columns].apply(lambda x: x.astype('category'))

# Encode categorical columns
df[categorical_columns] = df[categorical_columns].apply(lambda x: x.cat.codes)

# %%
# Save the cleaned dataset
cleaned_file_path = 'HR_Data_Cleaned_Additional_Changes.csv'
df.to_csv(cleaned_file_path, index=False)

# %% [markdown]
# ### Visualizations

# %%
x = pd.read_csv('HR_Data_Cleaned_Additional_Changes.csv')

# %%
x
# Out:
#       Age  EmployeeAttrition  TravelFrequency  DailyIncome  Department  \
# 0      41                  1                2         1102           2
# 1      49                  0                1          279           1
# 2      37                  1                2         1373           1
# 3      33                  0                1         1392           1
# 4      27                  0                2          591           1
# ...   ...                ...              ...          ...         ...
# 1465   36                  0                1          884           1
# 1466   39                  0                2          613           1
# 1467   27                  0                2          155           1
# 1468   49                  0                1         1023           2
# 1469   34                  0                2          628           1
#
#       DistanceFromHome  Education  EducationField  EmployeeNumber  \
# ...

# %% [markdown]
# #### Distribution of Age

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x['Age'], kde=True, color='green', bins=30)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Attrition Rate by Department

# %%
x['EmployeeAttrition'] = x['EmployeeAttrition'].astype(str)

plt.figure(figsize=(10, 6))
sns.countplot(x='Department', hue='EmployeeAttrition', data=x)
plt.title('Attrition Rate by Department')
plt.xlabel('Department')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Correlation Heatmap

# %%
plt.figure(figsize=(14, 12))
corr = x.corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# #### Bar Plot of Job Satisfaction

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='JobSatisfaction', data=df)
plt.title('Job Satisfaction Distribution')
plt.xlabel('Job Satisfaction Level')
plt.ylabel('Count')
plt.show()
